# %%
#spectrogram processer2

# %%
import librosa
import pandas
import matplotlib.pyplot as plt
import os
import pickle
import librosa
import numpy as np
import json
import librosa.display
import IPython.display as ipd

# %%
class Loader:
    """Loader is responsible for loading an audio file."""

    def __init__(self, sample_rate, mono):
        self.sample_rate = sample_rate
        self.mono = mono

    def load(self, file_path):
        signal = librosa.load(file_path,
                              sr=self.sample_rate,
                              mono=self.mono)[0]
        return signal

# %%
class MelSpectrogramExtractor:
    """ extracts mel spectograms (in db) from a time series signal """
    def __init__(self, frame_size, hop_length):
        self.frame_size = frame_size
        self.hop_length = hop_length
        
    def extract(self, signal):
        spec = librosa.feature.melspectrogram(y = signal)
        mel_spectrogram = librosa.amplitude_to_db(spec, ref = np.max)
        return mel_spectrogram

# %%
class Saver:
    """ saver is responsible to save features """

    def __init__(self, feature_save_dir):
        self.feature_save_dir = feature_save_dir

    def save_feature(self, feature, file_path):
        save_path = self._generate_save_path(file_path)
        np.save(save_path, feature)

    
    def _save(data, save_path):
        with open(save_path, "wb") as f:
            pickle.dump(data, f)

    def _generate_save_path(self, file_path):
        file_name = os.path.split(file_path)[1]
        save_path = os.path.join(self.feature_save_dir, file_name + ".npy")
        return save_path

# %%
class PreprocessingPipeline:

    def __init__(self):
        self.extractor = None
        self.normaliser = None
        self.saver = None
        self._loader = None
        #self._num_expected_samples = None

    
    def loader(self):
        return self._loader

    def process(self, audio_files_dir):
        for root, _, files in os.walk(audio_files_dir):
            for file in files:
                file_path = os.path.join(root, file)
                self._process_file(file_path)
                print(f"Processed file {file_path}")
        
    def _process_file(self, file_path):
        signal = self.loader.load(file_path)
        feature = self.extractor.extract(signal)
        save_path = self.saver.save_feature(feature, file_path)

# %%
if __name__ == "__main__":
    FRAME_SIZE = 512
    HOP_LENGTH = 256
    SAMPLE_RATE = 16000
    MONO = True

    SPECTROGRAMS_SAVE_DIR = "Desktop/spectrograms"
    FILES_DIR = "demo"

    # instantiate all objects
    loader = Loader(SAMPLE_RATE, MONO)
    mel_spectrogram_extractor = MelSpectrogramExtractor(FRAME_SIZE, HOP_LENGTH)
    saver = Saver(SPECTROGRAMS_SAVE_DIR)

    preprocessing_pipeline = PreprocessingPipeline()
    preprocessing_pipeline.loader = loader
    preprocessing_pipeline.extractor = mel_spectrogram_extractor
    preprocessing_pipeline.saver = saver

    preprocessing_pipeline.process(FILES_DIR)
# Out:
# Processed file demo\101415-3-0-2.wav
# Processed file demo\101415-3-0-3.wav
# Processed file demo\101415-3-0-8.wav
# Processed file demo\102106-3-0-0.wav
# Processed file demo\102305-6-0-0.wav
# Processed file demo\102842-3-0-1.wav
# Processed file demo\102842-3-1-0.wav
# Processed file demo\102842-3-1-5.wav
# Processed file demo\102842-3-1-6.wav
# Processed file demo\103074-7-0-0.wav
# Processed file demo\103074-7-0-1.wav
# Processed file demo\103074-7-0-2.wav
# Processed file demo\103074-7-1-0.wav
# Processed file demo\103074-7-1-1.wav
# Processed file demo\103074-7-1-2.wav
# Processed file demo\103074-7-1-3.wav
# Processed file demo\103074-7-1-4.wav
# Processed file demo\103074-7-1-5.wav
# Processed file demo\103074-7-1-6.wav
# Processed file demo\103074-7-2-0.wav
# Processed file demo\103074-7-3-0.wav
# Processed file demo\103074-7-3-1.wav
# Processed file demo\103074-7-3-2.wav
# Processed file demo\103074-7-3-3.wav
# Processed file demo\103074-7-4-0.wav
# Processed file demo\103074-7-4-1.wav
# Processed file demo\103074-7-4-2.wav
# Processed file demo\103074-7-4-3.wav
# Processed file demo\103074-7-4-4.wav
# Processed file demo\103074-7-4-5.wav
# Processed file demo\103074-7-4-6.wav
# Processed file demo\103258-5-0-0.wav
# Processed file demo\103258-5-0-1.wav
# Processed file demo\103258-5-0-10.wav
# Processed file demo\103258-5-0-11.wav
# Processed file demo\103258-5-0-12.wav
# Processed file demo\103258-5-0-13.wav
# Processed file demo\103258-5-0-14.wav
# Processed file demo\103258-5-0-15.wav
# Processed file demo\103258-5-0-16.wav
# Processed file demo\103258-5-0-17.wav
# Processed file demo\103258-5-0-18.wav
# Processed file demo\103258-5-0-19.wav
# Processed file demo\103258-5-0-2.wav
# Processed file demo\103258-5-0-3.wav
# Processed file demo\103258-5-0-4.wav
# Processed file demo\103258-5-0-5.wav
# Processed file demo\103258-5-0-6.wav
# Processed file demo\103258-5-0-7.wav
# Processed file demo\103258-5-0-8.wav
# Processed file demo\103258-5-0-9.wav
# Processed file demo\105415-2-0-1.wav
# Processed file demo\105415-2-0-15.wav
# Processed file demo\105415-2-0-19.wav
# Processed file demo\105415-2-0-21.wav
# Processed file demo\105415-2-0-24.wav
# Processed file demo\105415-2-0-4.wav
# Processed file demo\105415-2-0-6.wav
# Processed file demo\105415-2-0-8.wav
# Processed file demo\106905-8-0-0.wav
# Processed file demo\106905-8-0-1.wav
# Processed file demo\106905-8-0-2.wav
# Processed file demo\106905-8-0-3.wav
# Processed file demo\108041-9-0-11.wav
# Processed file demo\108041-9-0-2.wav
# Processed file demo\108041-9-0-4.wav
# Processed file demo\108041-9-0-5.wav
# Processed file demo\108041-9-0-6.wav
# Processed file demo\108041-9-0-7.wav
# Processed file demo\108041-9-0-9.wav
# Processed file demo\108362-2-0-11.wav
# Processed file demo\108362-2-0-12.wav
# Processed file demo\108362-2-0-21.wav
# Processed file demo\108362-2-0-23.wav
# Processed file demo\108362-2-0-29.wav
# Processed file demo\108362-2-0-30.wav
# Processed file demo\108362-2-0-7.wav
# Processed file demo\108362-2-0-9.wav
# Processed file demo\113205-5-0-0.wav
# Processed file demo\113205-5-1-0.wav
# Processed file demo\113205-5-1-1.wav
# Processed file demo\113205-5-1-2.wav
# Processed file demo\113205-5-1-3.wav
# Processed file demo\113205-5-1-4.wav
# Processed file demo\113205-5-1-5.wav
# Processed file demo\113205-5-1-6.wav
# Processed file demo\113205-5-1-7.wav
# Processed file demo\113205-5-1-8.wav
# Processed file demo\113205-5-1-9.wav
# Processed file demo\114587-3-0-2.wav
# Processed file demo\114587-3-0-4.wav
# Processed file demo\114587-3-0-5.wav
# Processed file demo\114587-3-0-7.wav
# Processed file demo\118101-3-0-0.wav
# Processed file demo\118101-3-0-3.wav
# Processed file demo\118101-3-0-4.wav
# Processed file demo\118101-3-0-6.wav
# Processed file demo\118279-8-0-0.wav
# Processed file demo\118279-8-0-1.wav
# Processed file demo\118279-8-0-10.wav
# Processed file demo\118279-8-0-11.wav
# Processed file demo\118279-8-0-12.wav
# Processed file demo\118279-8-0-13.wav
# Processed file demo\118279-8-0-14.wav
# Processed file demo\118279-8-0-2.wav
# Processed file demo\118279-8-0-3.wav
# Processed file demo\118279-8-0-4.wav
# Processed file demo\118279-8-0-5.wav
# Processed file demo\118279-8-0-6.wav
# Processed file demo\118279-8-0-7.wav
# Processed file demo\118279-8-0-8.wav
# Processed file demo\118279-8-0-9.wav
# Processed file demo\118963-3-0-0.wav
# Processed file demo\119455-5-0-0.wav
# Processed file demo\119455-5-0-1.wav
# Processed file demo\119455-5-0-2.wav
# Processed file demo\119455-5-0-3.wav
# Processed file demo\119455-5-0-4.wav
# Processed file demo\119455-5-0-5.wav
# Processed file demo\119455-5-0-6.wav
# Processed file demo\119455-5-0-7.wav
# Processed file demo\122690-6-0-0.wav
# Processed file demo\124489-9-0-12.wav
# Processed file demo\124489-9-0-14.wav
# Processed file demo\124489-9-0-16.wav
# Processed file demo\124489-9-0-17.wav
# Processed file demo\124489-9-0-18.wav
# Processed file demo\124489-9-0-6.wav
# Processed file demo\125791-3-0-12.wav
# Processed file demo\125791-3-0-13.wav
# Processed file demo\125791-3-0-15.wav
# Processed file demo\125791-3-0-9.wav
# Processed file demo\127873-0-0-0.wav
# Processed file demo\130030-3-0-0.wav
# Processed file demo\132016-9-0-0.wav
# Processed file demo\132016-9-0-11.wav
# Processed file demo\132016-9-0-14.wav
# Processed file demo\132016-9-0-16.wav
# Processed file demo\132016-9-0-20.wav
# Processed file demo\132016-9-0-6.wav
# Processed file demo\134717-0-0-0.wav
# Processed file demo\134717-0-0-1.wav
# Processed file demo\134717-0-0-12.wav
# Processed file demo\134717-0-0-13.wav
# Processed file demo\134717-0-0-14.wav
# Processed file demo\134717-0-0-15.wav
# Processed file demo\134717-0-0-16.wav
# Processed file demo\134717-0-0-18.wav
# Processed file demo\134717-0-0-19.wav
# Processed file demo\134717-0-0-2.wav
# Processed file demo\134717-0-0-20.wav
# Processed file demo\134717-0-0-21.wav
# Processed file demo\134717-0-0-22.wav
# Processed file demo\134717-0-0-23.wav
# Processed file demo\134717-0-0-24.wav
# Processed file demo\134717-0-0-25.wav
# Processed file demo\134717-0-0-26.wav
# Processed file demo\134717-0-0-27.wav
# Processed file demo\134717-0-0-28.wav
# Processed file demo\134717-0-0-4.wav
# Processed file demo\134717-0-0-5.wav
# Processed file demo\134717-0-0-6.wav
# Processed file demo\134717-0-0-7.wav
# Processed file demo\134717-0-0-8.wav
# Processed file demo\134717-0-0-9.wav
# Processed file demo\135776-2-0-32.wav
# Processed file demo\135776-2-0-37.wav
# Processed file demo\135776-2-0-40.wav
# Processed file demo\135776-2-0-49.wav
# Processed file demo\135776-2-0-50.wav
# Processed file demo\135776-2-0-65.wav
# Processed file demo\135776-2-0-85.wav
# Processed file demo\135776-2-0-90.wav
# Processed file demo\137156-9-0-28.wav
# Processed file demo\137156-9-0-30.wav
# Processed file demo\137156-9-0-31.wav
# Processed file demo\137156-9-0-5.wav
# Processed file demo\137156-9-0-73.wav
# Processed file demo\137156-9-0-79.wav
# Processed file demo\138015-3-0-1.wav
# Processed file demo\138015-3-0-5.wav
# Processed file demo\138015-3-0-7.wav
# Processed file demo\138031-2-0-13.wav
# Processed file demo\138031-2-0-2.wav
# Processed file demo\138031-2-0-22.wav
# Processed file demo\138031-2-0-23.wav
# Processed file demo\138031-2-0-28.wav
# Processed file demo\138031-2-0-45.wav
# Processed file demo\138031-2-0-47.wav
# Processed file demo\138031-2-0-7.wav
# Processed file demo\139951-9-0-13.wav
# Processed file demo\139951-9-0-17.wav
# Processed file demo\139951-9-0-29.wav
# Processed file demo\139951-9-0-33.wav
# Processed file demo\139951-9-0-45.wav
# Processed file demo\139951-9-0-9.wav
# Processed file demo\14113-4-0-0.wav
# Processed file demo\14113-4-0-1.wav
# Processed file demo\143604-5-0-0.wav
# Processed file demo\143651-2-0-0.wav
# Processed file demo\143651-2-0-16.wav
# Processed file demo\143651-2-0-20.wav
# Processed file demo\143651-2-0-22.wav
# Processed file demo\143651-2-0-39.wav
# Processed file demo\143651-2-0-55.wav
# Processed file demo\143651-2-0-59.wav
# Processed file demo\143651-2-0-63.wav
# Processed file demo\146186-5-0-0.wav
# Processed file demo\146186-5-0-1.wav
# Processed file demo\146186-5-0-10.wav
# Processed file demo\146186-5-0-11.wav
# Processed file demo\146186-5-0-12.wav
# Processed file demo\146186-5-0-13.wav
# Processed file demo\146186-5-0-2.wav
# Processed file demo\146186-5-0-3.wav
# Processed file demo\146186-5-0-4.wav
# Processed file demo\146186-5-0-5.wav
# Processed file demo\146186-5-0-6.wav
# Processed file demo\146186-5-0-7.wav
# Processed file demo\146186-5-0-8.wav
# Processed file demo\146186-5-0-9.wav
# Processed file demo\147764-4-0-0.wav
# Processed file demo\147764-4-1-0.wav
# Processed file demo\147764-4-2-0.wav
# Processed file demo\147764-4-3-0.wav
# Processed file demo\147764-4-4-0.wav
# Processed file demo\147764-4-4-1.wav
# Processed file demo\147764-4-4-2.wav
# Processed file demo\147764-4-5-0.wav
# Processed file demo\147764-4-6-0.wav
# Processed file demo\147764-4-7-0.wav
# Processed file demo\147764-4-8-0.wav
# Processed file demo\150341-3-0-0.wav
# Processed file demo\150341-3-1-0.wav
# Processed file demo\151977-0-0-0.wav
# Processed file demo\151977-0-0-1.wav
# Processed file demo\151977-0-0-10.wav
# Processed file demo\151977-0-0-11.wav
# Processed file demo\151977-0-0-12.wav
# Processed file demo\151977-0-0-13.wav
# Processed file demo\151977-0-0-2.wav
# Processed file demo\151977-0-0-3.wav
# Processed file demo\151977-0-0-4.wav
# Processed file demo\151977-0-0-5.wav
# Processed file demo\151977-0-0-6.wav
# Processed file demo\151977-0-0-7.wav
# Processed file demo\151977-0-0-8.wav
# Processed file demo\151977-0-0-9.wav
# Processed file demo\155202-9-0-124.wav
# Processed file demo\155202-9-0-126.wav
# Processed file demo\155202-9-0-135.wav
# Processed file demo\155202-9-0-38.wav
# Processed file demo\155202-9-0-42.wav
# Processed file demo\155202-9-0-6.wav
# Processed file demo\155310-3-0-0.wav
# Processed file demo\15564-2-0-0.wav
# Processed file demo\15564-2-0-1.wav
# Processed file demo\15564-2-0-2.wav
# Processed file demo\156194-1-0-0.wav
# Processed file demo\157867-8-0-0.wav
# Processed file demo\157867-8-0-1.wav
# Processed file demo\157867-8-0-10.wav
# Processed file demo\157867-8-0-11.wav
# Processed file demo\157867-8-0-12.wav
# Processed file demo\157867-8-0-13.wav
# Processed file demo\157867-8-0-14.wav
# Processed file demo\157867-8-0-15.wav
# Processed file demo\157867-8-0-16.wav
# Processed file demo\157867-8-0-17.wav
# Processed file demo\157867-8-0-18.wav
# Processed file demo\157867-8-0-19.wav
# Processed file demo\157867-8-0-2.wav
# Processed file demo\157867-8-0-20.wav
# Processed file demo\157867-8-0-21.wav
# Processed file demo\157867-8-0-22.wav
# Processed file demo\157867-8-0-23.wav
# Processed file demo\157867-8-0-24.wav
# Processed file demo\157867-8-0-25.wav
# Processed file demo\157867-8-0-26.wav
# Processed file demo\157867-8-0-27.wav
# Processed file demo\157867-8-0-28.wav
# Processed file demo\157867-8-0-3.wav
# Processed file demo\157867-8-0-4.wav
# Processed file demo\157867-8-0-5.wav
# Processed file demo\157867-8-0-6.wav
# Processed file demo\157867-8-0-7.wav
# Processed file demo\157867-8-0-8.wav
# Processed file demo\157867-8-0-9.wav
# Processed file demo\159738-8-0-0.wav
# Processed file demo\159738-8-0-1.wav
# Processed file demo\159738-8-0-10.wav
# Processed file demo\159738-8-0-11.wav
# Processed file demo\159738-8-0-12.wav
# Processed file demo\159738-8-0-13.wav
# Processed file demo\159738-8-0-14.wav
# Processed file demo\159738-8-0-15.wav
# Processed file demo\159738-8-0-16.wav
# Processed file demo\159738-8-0-17.wav
# Processed file demo\159738-8-0-18.wav
# Processed file demo\159738-8-0-19.wav
# Processed file demo\159738-8-0-2.wav
# Processed file demo\159738-8-0-3.wav
# Processed file demo\159738-8-0-4.wav
# Processed file demo\159738-8-0-5.wav
# Processed file demo\159738-8-0-6.wav
# Processed file demo\159738-8-0-7.wav
# Processed file demo\159738-8-0-8.wav
# Processed file demo\159738-8-0-9.wav
# Processed file demo\160009-2-0-1.wav
# Processed file demo\160009-2-0-11.wav
# Processed file demo\160009-2-0-22.wav
# Processed file demo\160009-2-0-30.wav
# Processed file demo\160009-2-0-31.wav
# Processed file demo\160009-2-0-47.wav
# Processed file demo\160009-2-0-5.wav
# Processed file demo\160009-2-0-50.wav
# Processed file demo\160094-3-0-0.wav
# Processed file demo\161702-9-0-26.wav
# Processed file demo\161702-9-0-30.wav
# Processed file demo\161702-9-0-37.wav
# Processed file demo\161702-9-0-45.wav
# Processed file demo\161702-9-0-6.wav
# Processed file demo\161702-9-0-8.wav
# Processed file demo\162540-1-0-0.wav
# Processed file demo\162540-1-1-0.wav
# Processed file demo\162540-1-2-0.wav
# Processed file demo\162703-1-0-0.wav
# Processed file demo\164053-8-0-0.wav
# Processed file demo\164053-8-1-0.wav
# Processed file demo\164053-8-2-0.wav
# Processed file demo\164053-8-2-1.wav
# Processed file demo\164053-8-2-2.wav
# Processed file demo\164053-8-2-3.wav
# Processed file demo\164053-8-3-0.wav
# Processed file demo\164312-3-0-0.wav
# Processed file demo\164312-3-1-0.wav
# Processed file demo\164312-3-3-0.wav
# Processed file demo\164312-3-4-0.wav
# Processed file demo\165067-2-0-111.wav
# Processed file demo\165067-2-0-112.wav
# Processed file demo\165067-2-0-35.wav
# Processed file demo\165067-2-0-56.wav
# Processed file demo\165067-2-0-72.wav
# Processed file demo\165067-2-0-9.wav
# Processed file demo\165067-2-0-91.wav
# Processed file demo\165642-4-0-0.wav
# Processed file demo\165645-4-0-0.wav
# Processed file demo\165645-4-1-0.wav
# Processed file demo\165645-4-2-0.wav
# Processed file demo\165645-4-3-0.wav
# Processed file demo\165645-4-4-0.wav
# Processed file demo\165645-4-5-0.wav
# Processed file demo\166268-3-0-0.wav
# Processed file demo\166268-3-1-0.wav
# Processed file demo\166268-3-2-0.wav
# Processed file demo\172314-9-0-22.wav
# Processed file demo\172314-9-0-40.wav
# Processed file demo\172314-9-0-51.wav
# Processed file demo\172314-9-0-52.wav
# Processed file demo\172314-9-0-72.wav
# Processed file demo\172314-9-0-80.wav
# Processed file demo\174276-7-0-0.wav
# Processed file demo\174276-7-1-0.wav
# Processed file demo\174276-7-2-0.wav
# Processed file demo\174276-7-3-0.wav
# Processed file demo\174276-7-4-0.wav
# Processed file demo\174276-7-5-0.wav
# Processed file demo\174276-7-6-0.wav
# Processed file demo\174290-6-0-0.wav
# Processed file demo\174290-6-1-0.wav
# Processed file demo\174290-6-2-0.wav
# Processed file demo\174290-6-3-0.wav
# Processed file demo\174294-6-0-0.wav
# Processed file demo\174294-6-1-0.wav
# Processed file demo\174294-6-2-0.wav
# Processed file demo\175845-1-0-0.wav
# Processed file demo\175851-1-0-0.wav
# Processed file demo\17592-5-0-0.wav
# Processed file demo\17592-5-1-0.wav
# Processed file demo\17592-5-1-1.wav
# Processed file demo\17592-5-1-2.wav
# Processed file demo\17592-5-1-3.wav
# Processed file demo\176257-3-0-0.wav
# Processed file demo\176258-3-1-12.wav
# Processed file demo\176258-3-1-13.wav
# Processed file demo\176258-3-1-18.wav
# Processed file demo\176258-3-1-2.wav
# Processed file demo\176638-1-0-0.wav
# Processed file demo\176638-1-1-0.wav
# Processed file demo\176714-2-0-18.wav
# Processed file demo\176714-2-0-23.wav
# Processed file demo\176714-2-0-26.wav
# Processed file demo\176714-2-0-33.wav
# Processed file demo\176714-2-0-40.wav
# Processed file demo\176714-2-0-51.wav
# Processed file demo\176714-2-0-55.wav
# Processed file demo\176714-2-0-77.wav
# Processed file demo\176787-5-0-0.wav
# Processed file demo\176787-5-0-1.wav
# Processed file demo\176787-5-0-10.wav
# Processed file demo\176787-5-0-11.wav
# Processed file demo\176787-5-0-12.wav
# Processed file demo\176787-5-0-13.wav
# Processed file demo\176787-5-0-14.wav
# Processed file demo\176787-5-0-15.wav
# Processed file demo\176787-5-0-16.wav
# Processed file demo\176787-5-0-17.wav
# Processed file demo\176787-5-0-18.wav
# Processed file demo\176787-5-0-19.wav
# Processed file demo\176787-5-0-2.wav
# Processed file demo\176787-5-0-20.wav
# Processed file demo\176787-5-0-21.wav
# Processed file demo\176787-5-0-22.wav
# Processed file demo\176787-5-0-23.wav
# Processed file demo\176787-5-0-24.wav
# Processed file demo\176787-5-0-25.wav
# Processed file demo\176787-5-0-26.wav
# Processed file demo\176787-5-0-27.wav
# Processed file demo\176787-5-0-28.wav
# Processed file demo\176787-5-0-29.wav
# Processed file demo\176787-5-0-3.wav
# Processed file demo\176787-5-0-30.wav
# Processed file demo\176787-5-0-4.wav
# Processed file demo\176787-5-0-5.wav
# Processed file demo\176787-5-0-6.wav
# Processed file demo\176787-5-0-7.wav
# Processed file demo\176787-5-0-8.wav
# Processed file demo\176787-5-0-9.wav
# Processed file demo\177621-0-0-0.wav
# Processed file demo\177621-0-0-100.wav
# Processed file demo\177621-0-0-104.wav
# Processed file demo\177621-0-0-105.wav
# Processed file demo\177621-0-0-109.wav
# Processed file demo\177621-0-0-117.wav
# Processed file demo\177621-0-0-120.wav
# Processed file demo\177621-0-0-126.wav
# Processed file demo\177621-0-0-127.wav
# Processed file demo\177621-0-0-128.wav
# Processed file demo\177621-0-0-145.wav
# Processed file demo\177621-0-0-147.wav
# Processed file demo\177621-0-0-2.wav
# Processed file demo\177621-0-0-27.wav
# Processed file demo\177621-0-0-31.wav
# Processed file demo\177621-0-0-35.wav
# Processed file demo\177621-0-0-46.wav
# Processed file demo\177621-0-0-47.wav
# Processed file demo\177621-0-0-48.wav
# Processed file demo\177621-0-0-54.wav
# Processed file demo\177621-0-0-57.wav
# Processed file demo\177621-0-0-80.wav
# Processed file demo\177621-0-0-88.wav
# Processed file demo\177621-0-0-91.wav
# Processed file demo\177621-0-0-93.wav
# Processed file demo\17913-4-0-0.wav
# Processed file demo\17913-4-0-1.wav
# Processed file demo\17913-4-0-2.wav
# Processed file demo\17913-4-1-0.wav
# Processed file demo\17913-4-2-0.wav
# Processed file demo\179858-1-0-0.wav
# Processed file demo\179867-1-0-0.wav
# Processed file demo\180256-3-0-0.wav
# Processed file demo\180256-3-0-1.wav
# Processed file demo\180256-3-0-2.wav
# Processed file demo\180256-3-0-3.wav
# Processed file demo\180937-7-0-0.wav
# Processed file demo\180937-7-0-1.wav
# Processed file demo\180937-7-0-2.wav
# Processed file demo\180937-7-0-4.wav
# Processed file demo\180937-7-0-5.wav
# Processed file demo\180937-7-0-6.wav
# Processed file demo\180937-7-1-0.wav
# Processed file demo\180937-7-1-1.wav
# Processed file demo\180937-7-1-10.wav
# Processed file demo\180937-7-1-11.wav
# Processed file demo\180937-7-1-12.wav
# Processed file demo\180937-7-1-13.wav
# Processed file demo\180937-7-1-14.wav
# Processed file demo\180937-7-1-15.wav
# Processed file demo\180937-7-1-2.wav
# Processed file demo\180937-7-1-3.wav
# Processed file demo\180937-7-1-4.wav
# Processed file demo\180937-7-1-5.wav
# Processed file demo\180937-7-1-6.wav
# Processed file demo\180937-7-1-7.wav
# Processed file demo\180937-7-1-8.wav
# Processed file demo\180937-7-1-9.wav
# Processed file demo\180937-7-2-0.wav
# Processed file demo\180937-7-2-1.wav
# Processed file demo\180937-7-2-10.wav
# Processed file demo\180937-7-2-2.wav
# Processed file demo\180937-7-2-3.wav
# Processed file demo\180937-7-2-4.wav
# Processed file demo\180937-7-2-5.wav
# Processed file demo\180937-7-2-6.wav
# Processed file demo\180937-7-2-7.wav
# Processed file demo\180937-7-2-8.wav
# Processed file demo\180937-7-2-9.wav
# Processed file demo\180937-7-3-0.wav
# Processed file demo\180937-7-3-1.wav
# Processed file demo\180937-7-3-10.wav
# Processed file demo\180937-7-3-11.wav
# Processed file demo\180937-7-3-12.wav
# Processed file demo\180937-7-3-13.wav
# Processed file demo\180937-7-3-14.wav
# Processed file demo\180937-7-3-15.wav
# Processed file demo\180937-7-3-17.wav
# Processed file demo\180937-7-3-18.wav
# Processed file demo\180937-7-3-19.wav
# Processed file demo\180937-7-3-2.wav
# Processed file demo\180937-7-3-20.wav
# Processed file demo\180937-7-3-21.wav
# Processed file demo\180937-7-3-22.wav
# Processed file demo\180937-7-3-23.wav
# Processed file demo\180937-7-3-24.wav
# Processed file demo\180937-7-3-26.wav
# Processed file demo\180937-7-3-27.wav
# Processed file demo\180937-7-3-28.wav
# Processed file demo\180937-7-3-29.wav
# Processed file demo\180937-7-3-3.wav
# Processed file demo\180937-7-3-30.wav
# Processed file demo\180937-7-3-31.wav
# Processed file demo\180937-7-3-32.wav
# Processed file demo\180937-7-3-33.wav
# Processed file demo\180937-7-3-4.wav
# Processed file demo\180937-7-3-5.wav
# Processed file demo\180937-7-3-6.wav
# Processed file demo\180937-7-3-7.wav
# Processed file demo\180937-7-3-8.wav
# Processed file demo\180937-7-3-9.wav
# Processed file demo\180937-7-4-0.wav
# Processed file demo\180937-7-4-10.wav
# Processed file demo\180937-7-4-11.wav
# Processed file demo\180937-7-4-12.wav
# Processed file demo\180937-7-4-13.wav
# Processed file demo\180937-7-4-14.wav
# Processed file demo\180937-7-4-2.wav
# Processed file demo\180937-7-4-3.wav
# Processed file demo\180937-7-4-4.wav
# Processed file demo\180937-7-4-5.wav
# Processed file demo\180937-7-4-6.wav
# Processed file demo\180937-7-4-7.wav
# Processed file demo\180937-7-4-8.wav
# Processed file demo\180937-7-4-9.wav
# Processed file demo\182800-2-0-0.wav
# Processed file demo\182800-2-1-0.wav
# Processed file demo\182800-2-2-0.wav
# Processed file demo\182800-2-2-1.wav
# Processed file demo\182800-2-2-2.wav
# Processed file demo\182800-2-2-3.wav
# Processed file demo\182800-2-3-0.wav
# Processed file demo\182800-2-3-1.wav
# Processed file demo\184355-1-0-0.wav
# Processed file demo\19026-1-0-0.wav
# Processed file demo\191431-9-0-26.wav
# Processed file demo\191431-9-0-30.wav
# Processed file demo\191431-9-0-61.wav
# Processed file demo\191431-9-0-66.wav
# Processed file demo\191431-9-0-73.wav
# Processed file demo\191431-9-0-8.wav
# Processed file demo\192124-2-0-0.wav
# Processed file demo\192124-2-0-11.wav
# Processed file demo\192124-2-0-12.wav
# Processed file demo\192124-2-0-15.wav
# Processed file demo\192124-2-0-3.wav
# Processed file demo\192124-2-0-4.wav
# Processed file demo\192124-2-0-5.wav
# Processed file demo\192124-2-0-7.wav
# Processed file demo\193394-3-0-10.wav
# Processed file demo\193394-3-0-11.wav
# Processed file demo\193394-3-0-4.wav
# Processed file demo\193394-3-0-7.wav
# Processed file demo\193698-2-0-112.wav
# Processed file demo\193698-2-0-113.wav
# Processed file demo\193698-2-0-114.wav
# Processed file demo\193698-2-0-140.wav
# Processed file demo\193698-2-0-42.wav
# Processed file demo\193698-2-0-58.wav
# Processed file demo\193698-2-0-64.wav
# Processed file demo\193698-2-0-89.wav
# Processed file demo\194732-9-0-126.wav
# Processed file demo\194732-9-0-163.wav
# Processed file demo\194732-9-0-171.wav
# Processed file demo\194732-9-0-175.wav
# Processed file demo\194732-9-0-191.wav
# Processed file demo\194732-9-0-41.wav
# Processed file demo\194732-9-0-95.wav
# Processed file demo\196065-2-0-0.wav
# Processed file demo\196079-2-0-0.wav
# Processed file demo\196087-2-0-0.wav
# Processed file demo\196400-6-0-0.wav
# Processed file demo\197073-3-0-0.wav
# Processed file demo\197073-3-3-0.wav
# Processed file demo\197073-3-4-3.wav
# Processed file demo\197073-3-7-0.wav
# Processed file demo\197318-6-0-0.wav
# Processed file demo\197318-6-1-0.wav
# Processed file demo\197318-6-10-0.wav
# Processed file demo\197318-6-11-0.wav
# Processed file demo\197318-6-12-0.wav
# Processed file demo\197318-6-2-0.wav
# Processed file demo\197318-6-3-0.wav
# Processed file demo\197318-6-4-0.wav
# Processed file demo\197318-6-5-0.wav
# Processed file demo\197318-6-6-0.wav
# Processed file demo\197318-6-7-0.wav
# Processed file demo\197318-6-8-0.wav
# Processed file demo\197318-6-9-0.wav
# Processed file demo\203356-3-0-0.wav
# Processed file demo\203356-3-0-1.wav
# Processed file demo\203356-3-0-2.wav
# Processed file demo\203356-3-0-3.wav
# Processed file demo\203440-3-0-0.wav
# Processed file demo\203440-3-0-1.wav
# Processed file demo\203440-3-0-5.wav
# Processed file demo\203440-3-0-6.wav
# Processed file demo\21684-9-0-12.wav
# Processed file demo\21684-9-0-25.wav
# Processed file demo\21684-9-0-30.wav
# Processed file demo\21684-9-0-39.wav
# Processed file demo\21684-9-0-5.wav
# Processed file demo\21684-9-0-50.wav
# Processed file demo\21684-9-0-7.wav
# Processed file demo\22962-4-0-0.wav
# Processed file demo\22962-4-0-1.wav
# Processed file demo\22962-4-0-2.wav
# Processed file demo\24074-1-0-0.wav
# Processed file demo\24074-1-0-1.wav
# Processed file demo\24074-1-0-10.wav
# Processed file demo\24074-1-0-11.wav
# Processed file demo\24074-1-0-12.wav
# Processed file demo\24074-1-0-13.wav
# Processed file demo\24074-1-0-2.wav
# Processed file demo\24074-1-0-3.wav
# Processed file demo\24074-1-0-4.wav
# Processed file demo\24074-1-0-5.wav
# Processed file demo\24074-1-0-6.wav
# Processed file demo\24074-1-0-7.wav
# Processed file demo\24074-1-0-8.wav
# Processed file demo\24074-1-0-9.wav
# Processed file demo\26270-9-0-19.wav
# Processed file demo\26270-9-0-23.wav
# Processed file demo\26270-9-0-3.wav
# Processed file demo\26270-9-0-30.wav
# Processed file demo\26270-9-0-32.wav
# Processed file demo\26270-9-0-35.wav
# Processed file demo\30823-8-0-0.wav
# Processed file demo\31323-3-0-1.wav
# Processed file demo\31323-3-0-2.wav
# Processed file demo\31323-3-0-20.wav
# Processed file demo\31323-3-0-22.wav
# Processed file demo\31840-3-0-0.wav
# Processed file demo\31840-3-1-0.wav
# Processed file demo\40722-8-0-0.wav
# Processed file demo\40722-8-0-1.wav
# Processed file demo\40722-8-0-2.wav
# Processed file demo\40722-8-0-3.wav
# Processed file demo\40722-8-0-4.wav
# Processed file demo\40722-8-0-5.wav
# Processed file demo\40722-8-0-6.wav
# Processed file demo\40722-8-0-7.wav
# Processed file demo\40722-8-0-8.wav
# Processed file demo\43786-3-0-0.wav
# Processed file demo\43786-3-1-0.wav
# Processed file demo\43806-8-0-0.wav
# Processed file demo\44736-5-0-0.wav
# Processed file demo\44736-5-0-1.wav
# Processed file demo\46654-6-0-0.wav
# Processed file demo\46656-6-0-0.wav
# Processed file demo\46656-6-1-0.wav
# Processed file demo\46656-6-2-0.wav
# Processed file demo\46656-6-3-0.wav
# Processed file demo\46656-6-4-0.wav
# Processed file demo\46656-6-5-0.wav
# Processed file demo\46669-4-0-0.wav
# Processed file demo\46669-4-0-10.wav
# Processed file demo\46669-4-0-2.wav
# Processed file demo\46669-4-0-24.wav
# Processed file demo\46669-4-0-26.wav
# Processed file demo\46669-4-0-3.wav
# Processed file demo\46669-4-0-30.wav
# Processed file demo\46669-4-0-31.wav
# Processed file demo\46669-4-0-32.wav
# Processed file demo\46669-4-0-33.wav
# Processed file demo\46669-4-0-35.wav
# Processed file demo\46669-4-0-36.wav
# Processed file demo\46669-4-0-37.wav
# Processed file demo\46669-4-0-39.wav
# Processed file demo\46669-4-0-4.wav
# Processed file demo\46669-4-0-45.wav
# Processed file demo\46669-4-0-48.wav
# Processed file demo\46669-4-0-49.wav
# Processed file demo\46669-4-0-54.wav
# Processed file demo\46669-4-0-61.wav
# Processed file demo\46669-4-0-63.wav
# Processed file demo\46669-4-0-8.wav
# Processed file demo\46669-4-0-9.wav
# Processed file demo\46918-5-0-0.wav
# Processed file demo\46918-5-0-1.wav
# Processed file demo\46918-5-0-2.wav
# Processed file demo\50901-0-0-0.wav
# Processed file demo\50901-0-1-0.wav
# Processed file demo\50901-0-1-1.wav
# Processed file demo\51022-3-13-0.wav
# Processed file demo\51022-3-29-0.wav
# Processed file demo\51022-3-30-4.wav
# Processed file demo\51022-3-7-0.wav
# Processed file demo\54858-3-0-0.wav
# Processed file demo\54858-3-1-2.wav
# Processed file demo\54858-3-2-0.wav
# Processed file demo\55020-4-0-0.wav
# Processed file demo\55020-4-0-1.wav
# Processed file demo\55020-4-0-10.wav
# Processed file demo\55020-4-0-11.wav
# Processed file demo\55020-4-0-12.wav
# Processed file demo\55020-4-0-13.wav
# Processed file demo\55020-4-0-14.wav
# Processed file demo\55020-4-0-2.wav
# Processed file demo\55020-4-0-3.wav
# Processed file demo\55020-4-0-4.wav
# Processed file demo\55020-4-0-5.wav
# Processed file demo\55020-4-0-6.wav
# Processed file demo\55020-4-0-7.wav
# Processed file demo\55020-4-0-8.wav
# Processed file demo\55020-4-0-9.wav
# Processed file demo\57320-0-0-0.wav
# Processed file demo\57320-0-0-10.wav
# Processed file demo\57320-0-0-11.wav
# Processed file demo\57320-0-0-13.wav
# Processed file demo\57320-0-0-15.wav
# Processed file demo\57320-0-0-21.wav
# Processed file demo\57320-0-0-22.wav
# Processed file demo\57320-0-0-24.wav
# Processed file demo\57320-0-0-27.wav
# Processed file demo\57320-0-0-31.wav
# Processed file demo\57320-0-0-32.wav
# Processed file demo\57320-0-0-33.wav
# Processed file demo\57320-0-0-34.wav
# Processed file demo\57320-0-0-36.wav
# Processed file demo\57320-0-0-37.wav
# Processed file demo\57320-0-0-38.wav
# Processed file demo\57320-0-0-39.wav
# Processed file demo\57320-0-0-4.wav
# Processed file demo\57320-0-0-42.wav
# Processed file demo\57320-0-0-45.wav
# Processed file demo\57320-0-0-5.wav
# Processed file demo\57320-0-0-6.wav
# Processed file demo\57320-0-0-7.wav
# Processed file demo\57320-0-0-9.wav
# Processed file demo\57553-3-0-0.wav
# Processed file demo\57553-3-1-0.wav
# Processed file demo\57553-3-2-0.wav
# Processed file demo\57584-4-0-0.wav
# Processed file demo\57584-4-0-1.wav
# Processed file demo\57584-4-0-2.wav
# Processed file demo\57584-4-0-3.wav
# Processed file demo\57584-4-0-4.wav
# Processed file demo\57584-4-0-5.wav
# Processed file demo\57584-4-0-6.wav
# Processed file demo\57584-4-0-7.wav
# Processed file demo\57584-4-0-8.wav
# Processed file demo\59277-0-0-0.wav
# Processed file demo\59277-0-0-1.wav
# Processed file demo\59277-0-0-2.wav
# Processed file demo\59277-0-0-3.wav
# Processed file demo\59277-0-0-4.wav
# Processed file demo\59277-0-0-5.wav
# Processed file demo\59277-0-0-6.wav
# Processed file demo\59277-0-0-7.wav
# Processed file demo\65749-3-1-12.wav
# Processed file demo\65749-3-1-14.wav
# Processed file demo\65749-3-1-24.wav
# Processed file demo\65749-3-1-9.wav
# Processed file demo\69304-9-0-0.wav
# Processed file demo\69304-9-0-12.wav
# Processed file demo\69304-9-0-14.wav
# Processed file demo\69304-9-0-15.wav
# Processed file demo\69304-9-0-6.wav
# Processed file demo\69304-9-0-7.wav
# Processed file demo\7061-6-0-0.wav
# Processed file demo\71087-4-0-0.wav
# Processed file demo\71087-4-1-0.wav
# Processed file demo\72261-3-0-17.wav
# Processed file demo\72261-3-0-23.wav
# Processed file demo\72261-3-0-27.wav
# Processed file demo\72261-3-0-6.wav
# Processed file demo\72579-3-0-0.wav
# Processed file demo\72579-3-0-2.wav
# Processed file demo\72579-3-0-3.wav
# Processed file demo\72579-3-0-4.wav
# Processed file demo\73277-9-0-0.wav
# Processed file demo\73277-9-0-16.wav
# Processed file demo\73277-9-0-17.wav
# Processed file demo\73277-9-0-19.wav
# Processed file demo\73277-9-0-24.wav
# Processed file demo\73277-9-0-28.wav
# Processed file demo\7383-3-0-0.wav
# Processed file demo\7383-3-0-1.wav
# Processed file demo\7383-3-1-0.wav
# Processed file demo\76093-6-0-0.wav
# Processed file demo\76093-6-1-0.wav
# Processed file demo\77246-6-0-0.wav
# Processed file demo\77766-9-0-0.wav
# Processed file demo\77766-9-0-3.wav
# Processed file demo\77766-9-0-4.wav
# Processed file demo\77766-9-0-5.wav
# Processed file demo\77766-9-0-6.wav
# Processed file demo\77766-9-0-7.wav
# Processed file demo\78360-4-0-0.wav
# Processed file demo\78360-4-0-1.wav
# Processed file demo\78360-4-0-11.wav
# Processed file demo\78360-4-0-12.wav
# Processed file demo\78360-4-0-14.wav
# Processed file demo\78360-4-0-15.wav
# Processed file demo\78360-4-0-16.wav
# Processed file demo\78360-4-0-17.wav
# Processed file demo\78360-4-0-18.wav
# Processed file demo\78360-4-0-19.wav
# Processed file demo\78360-4-0-2.wav
# Processed file demo\78360-4-0-20.wav
# Processed file demo\78360-4-0-21.wav
# Processed file demo\78360-4-0-22.wav
# Processed file demo\78360-4-0-23.wav
# Processed file demo\78360-4-0-3.wav
# Processed file demo\78360-4-0-4.wav
# Processed file demo\78360-4-0-5.wav
# Processed file demo\78360-4-0-6.wav
# Processed file demo\78360-4-0-7.wav
# Processed file demo\78360-4-0-8.wav
# Processed file demo\78360-4-0-9.wav
# Processed file demo\83199-9-0-0.wav
# Processed file demo\86278-6-0-0.wav
# Processed file demo\86279-3-0-0.wav
# Processed file demo\87275-1-0-0.wav
# Processed file demo\87275-1-1-0.wav
# Processed file demo\87275-1-2-0.wav
# Processed file demo\87275-1-3-0.wav
# Processed file demo\87275-1-4-0.wav
# C:\Users\HP\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=800
#   return f(*args, **kwargs)
# C:\Users\HP\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=960
#   return f(*args, **kwargs)
# C:\Users\HP\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1105
#   return f(*args, **kwargs)
# C:\Users\HP\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1745
#   return f(*args, **kwargs)
# Processed file demo\87275-1-5-0.wav
# Processed file demo\88466-7-0-0.wav
# Processed file demo\89212-3-0-0.wav
# Processed file demo\89948-5-0-0.wav
# Processed file demo\9031-3-1-0.wav
# Processed file demo\9031-3-2-0.wav
# Processed file demo\9031-3-3-0.wav
# Processed file demo\9031-3-4-0.wav
# Processed file demo\94868-1-0-0.wav
# Processed file demo\94868-1-1-0.wav
# Processed file demo\94868-1-2-0.wav
# Processed file demo\96158-4-0-0.wav
# Processed file demo\97317-2-0-22.wav
# Processed file demo\97317-2-0-23.wav
# Processed file demo\97317-2-0-25.wav
# Processed file demo\97317-2-0-28.wav
# Processed file demo\97317-2-0-34.wav
# Processed file demo\97317-2-0-36.wav
# Processed file demo\97317-2-0-5.wav
# Processed file demo\98223-7-0-0.wav
# Processed file demo\98223-7-1-0.wav
# Processed file demo\98223-7-10-0.wav
# Processed file demo\98223-7-2-0.wav
# Processed file demo\98223-7-3-0.wav
# Processed file demo\98223-7-4-0.wav
# Processed file demo\98223-7-5-0.wav
# Processed file demo\98223-7-6-0.wav
# Processed file demo\98223-7-7-0.wav
# Processed file demo\98223-7-8-0.wav
# Processed file demo\98223-7-9-0.wav
# Processed file demo\99180-9-0-0.wav
# Processed file demo\99180-9-0-2.wav
# Processed file demo\99180-9-0-36.wav
# Processed file demo\99180-9-0-48.wav
# Processed file demo\99180-9-0-49.wav
# Processed file demo\99180-9-0-7.wav

# %%
demo = np.load("spec save/7061-6-0-0.wav.npy")
print(demo)
plt.imshow(demo, cmap='gray')
plt.show()
# Out:
# [[-38.45302  -12.350655  -9.391476 ... -80.       -80.       -80.      ]
#  [-36.920097 -14.187853 -15.713837 ... -80.       -80.       -80.      ]
#  [-49.635918 -29.547428 -29.532976 ... -80.       -80.       -80.      ]
#  ...
#  [-80.       -66.241615 -68.63354  ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]
#  [-80.       -80.       -80.       ... -80.       -80.       -80.      ]]

# %%
demo = np.load("spec save/7383-3-0-0.wav.npy")
print(demo)
# Out:
# [[-80.      -80.      -80.      ... -80.      -80.      -80.     ]
#  [-80.      -80.      -80.      ... -80.      -80.      -80.     ]
#  [-80.      -76.40078 -75.38676 ... -80.      -80.      -80.     ]
#  ...
#  [-80.      -80.      -80.      ... -80.      -80.      -80.     ]
#  [-80.      -80.      -80.      ... -80.      -80.      -80.     ]
#  [-80.      -80.      -80.      ... -80.      -80.      -80.     ]]

# %%
plt.imshow(demo, cmap='gray')
plt.show()
